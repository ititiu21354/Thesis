# %%
import numpy as np
import pandas as pd
import copy
import random
from util.util_load         import read_txt
from util.util_display      import plot
from env_action.metaheu     import GeneticAlgorithm
from env_action.environment import FJSP_under_uncertainties_Env

maxtime                = 10
maxtimeacceptnewjob    = 150
defectProb             = 0.03

action_list            = ["exact", "GA", "LFOH", "LAPH", "LAP_LFO", "CDR1", "CDR2", "CDR4"]

J, I, K, p_ijk, h_ijk,   \
d_j, n_j, MC_ji, n_MC_ji,\
OperationPool          = read_txt("data\jobs.txt")

S_k                    = np.zeros((K))
S_j                    = np.zeros((J))
n_ops_left_j           = copy.deepcopy(n_j)
MB_info                = np.zeros((0))

t                      = 0
JSet                   = list(range(J))
OJSet                  = [[] for _ in range(J)]
for j in JSet:
    OJSet[j]           = [i for i in range(int(n_j[j]))]

# Preschedule
pre_GBest, X_ijk, S_ij, C_ij, C_j = GeneticAlgorithm (S_k, S_j, JSet, OJSet, J, I, K, 
                                                p_ijk, h_ijk, d_j, n_j, n_ops_left_j, 
                                                MC_ji, n_MC_ji, OperationPool, maxtime= 1000)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env     import DummyVecEnv
from stable_baselines3.common.callbacks   import BaseCallback, EvalCallback
from stable_baselines3.common.monitor     import Monitor
from stable_baselines3.common.env_checker import check_env 

from sb3_contrib                import QRDQN  # Import QRDQN for prioritized replay
from sb3_contrib.qrdqn.policies import MlpPolicy  # Use the correct MlpPolicy for QRDQN


env = FJSP_under_uncertainties_Env(J, I, K, X_ijk, S_ij, C_ij, C_j, p_ijk, d_j, n_j, MC_ji, n_MC_ji, h_ijk, OperationPool, maxtimeacceptnewjob, maxtime, defectProb, pre_GBest)

# check_env(env)
# obs = env.reset(seed=42)
# print("Observation:", obs)

# episodes = 10
# for episode in range(episodes):
# 	done = False
# 	obs = env.reset()
# 	while done == False:#not done:
# 		random_action = env.action_space.sample()
# 		obs, reward, done, truncated, info = env.step(random_action)
# 		print('reward', reward)

# %%
from stable_baselines3 import DQN
import os
import datetime
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback

# Create directories for models and logs
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
models_dir = f"models/DQN-{current_time}"
logdir = f"logs/DQN-{current_time}"
log_training_txt_dir = "log_training_txt"
log_training_excel_dir = "log_training_excel"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)
if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(log_training_txt_dir):
    os.makedirs(log_training_txt_dir)
if not os.path.exists(log_training_excel_dir):
    os.makedirs(log_training_excel_dir)

# Generate unique file names based on current time
log_file          = os.path.join(log_training_txt_dir,   f"training_{current_time}.txt")
excel_file        = os.path.join(log_training_excel_dir, f"training_{current_time}.xlsx")
action_count_file = os.path.join(log_training_txt_dir,   f"action_count_{current_time}.txt")
action_excel_file = os.path.join(log_training_excel_dir, f"action_count_{current_time}.xlsx")

# Define the custom callback -------------------------------------------------------------
class CustomCallback(BaseCallback):
    def __init__(self, log_dir, excel_file, txt_file, action_count_file, action_excel_file, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        self.log_dir = log_dir
        self.excel_file = excel_file
        self.txt_file = txt_file
        self.action_count_file = action_count_file
        self.action_excel_file = action_excel_file
        self.logs = []
        self.episode_rewards = []
        self.action_counts = {}
        self.episode_start = True

    def _on_training_start(self) -> None:
        # Initialize action counts
        self.action_counts = {action: 0 for action in action_list}

    def _on_step(self) -> bool:
        if self.episode_start:
            self.episode_rewards.append(0)
            self.episode_start = False

        # Record reward for the current step
        reward = self.locals['rewards'][0]
        self.episode_rewards[-1] += reward

        # Increment action count
        action = self.locals.get('actions', None)
        if action is not None:
            action_name = action_list[action[0]]
            self.action_counts[action_name] += 1
        
        return True

    def _on_rollout_end(self) -> None:
        # Called at the end of each episode
        sum_reward   = self.episode_rewards[-1] if self.episode_rewards else 0
        tardiness    = self.training_env.get_attr('unwrapped')[0].all_Tard
        
        self.logger.record('train/episode_reward',   sum_reward)
        self.logger.record('train/actual_tardiness', tardiness)

        self.logs.append({
            'episode': len(self.episode_rewards),
            'sum_reward': sum_reward,
            'tardiness': tardiness
        })
        self.episode_start = True

    def _on_training_end(self) -> None:
        # Save logs to Excel
        df = pd.DataFrame(self.logs)
        df.to_excel(self.excel_file, index=False)

        action_df = pd.DataFrame(list(self.action_counts.items()), columns=['Action', 'Count'])
        action_df.to_excel(self.action_excel_file, index=False)

        # Save logs to text file
        with open(self.txt_file, 'w') as f:
            f.write(df.to_string(index=False))
        with open(self.action_count_file, 'w') as f:
            f.write(action_df.to_string(index=False))


# Initialize the DQN model
model = DQN("MlpPolicy", 
            env, 
            verbose=1, 
            tensorboard_log=logdir, 
            train_freq=(1,"episode"),
            exploration_fraction=0.1,       # Fraction of the training period over which the exploration rate is annealed
            exploration_final_eps=0.02,     # Final value of the exploration rate after annealing
            exploration_initial_eps=1.0,    # Initial value of the exploration rate
            )

# Create the callback
callback = CustomCallback(log_dir=logdir, 
                          excel_file=excel_file,
                          txt_file=log_file,
                          action_count_file=action_count_file,
                          action_excel_file=action_excel_file,
                          verbose=1)


# Train the model
TIMESTEPS = 40000
model.learn(total_timesteps=TIMESTEPS, 
            reset_num_timesteps=False, 
            tb_log_name="DQN", 
            callback=callback)
model_path = os.path.join(models_dir, f"DQN_.zip")
model.save(model_path)

# tensorboard --logdir=logs/
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/DQN-2024-06-10_00-00-59\DQN_0
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.305   |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 20       |
# | train/              |          |
# |    actual_tardiness | 173      |
# |    episode_reward   | -0.449   |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.222   |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 40       |
# | train/              |          |
# |    actual_tardiness | 10       |
# |    episode_reward   | -0.0256  |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.179   |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 0        |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 60       |
# | train/              |          |
# |    actual_tardiness | 0        |
# |    episode_reward   | 0        |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.194   |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 0        |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 80       |
# | train/              |          |
# |    actual_tardiness | 20       |
# |    episode_reward   | -0.0524  |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.174   |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 100      |
# | train/              |          |
# |    actual_tardiness | 19       |
# |    episode_reward   | -0.0486  |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.156   |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 120      |
# | train/              |          |
# |    actual_tardiness | 7        |
# |    episode_reward   | -0.0179  |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 3        |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.152   |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 140      |
# | train/              |          |
# |    actual_tardiness | 7        |
# |    episode_reward   | -0.0181  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.578    |
# |    n_updates        | 7        |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.162   |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 160      |
# | train/              |          |
# |    actual_tardiness | 276      |
# |    episode_reward   | -0.721   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.721    |
# |    n_updates        | 11       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.173   |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 180      |
# | train/              |          |
# |    actual_tardiness | 56       |
# |    episode_reward   | -0.143   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.525    |
# |    n_updates        | 15       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.18    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1        |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 200      |
# | train/              |          |
# |    actual_tardiness | 38       |
# |    episode_reward   | -0.0982  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.519    |
# |    n_updates        | 19       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.182   |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 220      |
# | train/              |          |
# |    actual_tardiness | 25       |
# |    episode_reward   | -0.0641  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.543    |
# |    n_updates        | 23       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.193   |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 240      |
# | train/              |          |
# |    actual_tardiness | 334      |
# |    episode_reward   | -0.871   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.477    |
# |    n_updates        | 27       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.191   |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1        |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 260      |
# | train/              |          |
# |    actual_tardiness | 19       |
# |    episode_reward   | -0.0508  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.624    |
# |    n_updates        | 31       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.186   |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1        |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 280      |
# | train/              |          |
# |    actual_tardiness | 10       |
# |    episode_reward   | -0.0263  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.572    |
# |    n_updates        | 35       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.194   |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 300      |
# | train/              |          |
# |    actual_tardiness | 17       |
# |    episode_reward   | -0.0437  |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 39       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.19    |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 320      |
# | train/              |          |
# |    actual_tardiness | 98       |
# |    episode_reward   | -0.255   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.475    |
# |    n_updates        | 43       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.189   |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 340      |
# | train/              |          |
# |    actual_tardiness | 101      |
# |    episode_reward   | -0.261   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.406    |
# |    n_updates        | 47       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.187   |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    actual_tardiness | 45       |
# |    episode_reward   | -0.117   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.626    |
# |    n_updates        | 51       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.198   |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 380      |
# | train/              |          |
# |    actual_tardiness | 168      |
# |    episode_reward   | -0.44    |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.433    |
# |    n_updates        | 55       |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# ...
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    CDR1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.206   |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 1        |
# |    time_elapsed     | 11408    |
# |    total_timesteps  | 14120    |
# | train/              |          |
# |    actual_tardiness | 67       |
# |    episode_reward   | -0.174   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0576   |
# |    n_updates        | 2803     |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.206   |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 1        |
# |    time_elapsed     | 11430    |
# |    total_timesteps  | 14140    |
# | train/              |          |
# |    actual_tardiness | 2        |
# |    episode_reward   | -0.00511 |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0678   |
# |    n_updates        | 2807     |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.228   |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 1        |
# |    time_elapsed     | 11503    |
# |    total_timesteps  | 14160    |
# | train/              |          |
# |    actual_tardiness | 135      |
# |    episode_reward   | -0.364   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 2811     |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    CDR1
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5        |
# |    ep_rew_mean      | -0.226   |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 1        |
# |    time_elapsed     | 11530    |
# |    total_timesteps  | 14180    |
# | train/              |          |
# |    actual_tardiness | 93       |
# |    episode_reward   | -0.241   |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0379   |
# |    n_updates        | 2815     |
# ----------------------------------
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    LAP_LFO
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LAPH
# -------------------------------------------------
# Method selection:                    GA
# -------------------------------------------------
# Method selection:                    LFOH
# -------------------------------------------------
# Method selection:                    exact
# Solution Status: Optimal
# -------------------------------------------------
# Method selection:                    exact
# ---------------------------------------------------------------------------
# PulpSolverError                           Traceback (most recent call last)
# Cell In[3], line 116
#     114 # Train the model
#     115 TIMESTEPS = 40000
# --> 116 model.learn(total_timesteps=TIMESTEPS,
#     117             reset_num_timesteps=False,
#     118             tb_log_name="DQN",
#     119             callback=callback)
#     120 model_path = os.path.join(models_dir, f"DQN_.zip")
#     121 model.save(model_path)
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File d:\D\University\4th year\Thesis\CodeT6\env_action\environment.py:148, in FJSP_under_uncertainties_Env.step(self, action)
#     145 action_method                                = self.perform_action()
#     146 reschedule							         = action_method[action]
#     147 self.GBest, \
# --> 148 self.X_ijk, self.S_ij, self.C_ij, self.C_j   = reschedule()
#     150 self.X_ijk, self.S_ij, self.C_ij             = update_schedule(self.DSet, self.ODSet, self.X_ijk, self.S_ij, self.C_ij,\
#     151 														       self.X_previous, self.S_previous, self.C_previous)
#     153 # ---------------------------------------- State transition ------------------------------------------
#
# File d:\D\University\4th year\Thesis\CodeT6\env_action\action_space.py:117, in Method.exact(self)
#     115 problem.setObjective(lpSum([T_j[j] for j in self.JSet]))
#     116 solver = PULP_CBC_CMD(timeLimit=self.maxtime, msg=False)
# --> 117 problem.solve(solver)
#     118 # Print the solution status
#     119 print("Solution Status:", LpStatus[problem.status])
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\pulp\pulp.py:1883, in LpProblem.solve(self, solver, **kwargs)
#    1881 # time it
#    1882 self.startClock()
# -> 1883 status = solver.actualSolve(self, **kwargs)
#    1884 self.stopClock()
#    1885 self.restoreObjective(wasNone, dummyVar)
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\pulp\apis\coin_api.py:112, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     110 def actualSolve(self, lp, **kwargs):
#     111     """Solve a well formulated lp problem"""
# --> 112     return self.solve_CBC(lp, **kwargs)
#
# File c:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\pulp\apis\coin_api.py:181, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     179     if pipe:
#     180         pipe.close()
# --> 181     raise PulpSolverError(
#     182         "Pulp: Error while trying to execute, use msg=True for more details"
#     183         + self.path
#     184     )
#     185 if pipe:
#     186     pipe.close()
#
# PulpSolverError: Pulp: Error while trying to execute, use msg=True for more detailsc:\Users\ASUS\miniconda3\envs\dunnbebes\lib\site-packages\pulp\solverdir\cbc\win\64\cbc.exe
